# %%
import glob

pattern = '../**/*.ipynb'
query = 'vertical'

for filepath in glob.iglob(pattern, recursive=True):
    with open(filepath) as file:
        s = file.read()
        if (s.find(query) > -1):
            print(filepath)
# Out:
# ..\scien\(BETA)Event_Ratio_Comparison_Iterative.ipynb
# ..\scien\2Event_Ratio_Comparison_COMPLETE (5).ipynb
# ..\scien\2Event_Ratio_Comparison_COMPLETE (6).ipynb
# ..\scien\2Event_Ratio_Comparison_COMPLETE (7).ipynb
# ..\scien\2Event_Ratio_Comparison_COMPLETE (8).ipynb
# ..\scien\3Event_Ratio_Comparison.ipynb
# ..\scien\DT Data vs MC.ipynb
# ..\scien\DT MC Analysis.ipynb
# ..\scien\DT MC Analysis2.ipynb
# ..\scien\DT MC Analysis3.ipynb
# ..\scien\DT Secondary Peak Uncorrelated.ipynb
# ..\scien\Eta Analysis.ipynb
# ..\scien\Event_Ratio_Comparison.ipynb
# ..\scien\Event_Ratio_Comparison_Better.ipynb
# ..\scien\Event_Ratio_Comparison_COMPLETE.ipynb
# ..\scien\Event_Ratio_Comparison_DPhi.ipynb
# ..\scien\Event_Ratio_Comparison_Iterative-Copy1.ipynb
# ..\scien\Event_Ratio_Comparison_Iterative.ipynb
# ..\scien\junk.ipynb
# ..\scien\Phi Analysis.ipynb
# ..\scien\PLOT TESTS.ipynb
# ..\scien\ratio by events WORKING.ipynb
# ..\scien\ratio by events.ipynb
# ...
